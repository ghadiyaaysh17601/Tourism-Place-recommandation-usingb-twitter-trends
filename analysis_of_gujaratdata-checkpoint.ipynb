# %%
import numpy as np # numerical computing 
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt #visualization
import seaborn as sns #modern visualization

# %%
#load csv file
df=pd.read_csv(r"C:\Users\Ayush Patel\Downloads\data2.csv")

# %%
df.head()
# Out:
#    Location                                              Tweet
# 0  sasangir  #girnationalpark #girsafaribooking #girlionsaf...
# 1  sasangir  RT @BigCatsWildlife: 🔊 Sound up🔝😳😬🦁.\r\nAn Asi...
# 2  sasangir  World Animal Protection Welcomes Corporates Em...
# 3  sasangir  #girlionsafari #girnationalpark #girsafaribook...
# 4  sasangir  #girnationalpark #girsafaribooking \r\nThe Gir...

# %%
df.shape
# Out:
# (1379, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1379 entries, 0 to 1378
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Location  1379 non-null   object
#  1   Tweet     1379 non-null   object
# dtypes: object(2)
# memory usage: 21.7+ KB

# %%
plt.figure(figsize=(15,5))
sns.countplot('Location', data = df)
plt.title("Number of Tweet on specific location",fontsize=18,fontweight="bold")
plt.ylabel("Tweet", size = 25)
plt.xlabel("Places", size = 25)
plt.xticks(size = 20)
plt.yticks(size = 20)
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (array([  0.,  25.,  50.,  75., 100., 125., 150., 175., 200.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
MoM= df['Location'].value_counts()
MoM.head(10).plot(kind = 'bar',figsize=(12,8), fontsize=15, color='blue')
plt.title("Top 10 cities to visit in Gujarat",fontsize=18,fontweight="bold")
plt.ylabel("Frequency", size = 25)
plt.xlabel("Cities", size = 25)
# Out:
# Text(0.5, 0, 'Cities')

# %%
df['Location'].value_counts().plot(kind='pie', fontsize=14, autopct='%3.1f%%', 
                                               figsize=(10,7), shadow=True, startangle=135, legend=True, cmap='Oranges')


plt.title('Percentage of tweet on specific location')
# Out:
# Text(0.5, 1.0, 'Percentage of tweet on specific location')
